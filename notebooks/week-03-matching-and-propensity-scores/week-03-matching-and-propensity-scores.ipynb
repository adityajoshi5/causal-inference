# %% [markdown]
# # Week 3: Matching and Propensity Scores
#
# Starter notebook for the foundational causal inference course materials inspired by the Coursera course *A Crash Course in Causality: Inferring Causal Effects from Observational Data*.
#
# ## Learning goals
# - Summarize the main ideas from this module.
# - Add worked examples, notes, or references as you study.
# - Track open questions for later review.
#
# ## Module topics
# - Observational studies
# - Overview of matching
# - Matching directly on confounders
# - Greedy (nearest-neighbor) matching
# - Optimal matching
# - Assessing balance
# - Analyzing data after matching
# - Sensitivity analysis
# - Data example in R
# - Propensity scores
# - Propensity score matching
# - Propensity score matching in R
#
# ## Notes
# Use this section for concise study notes, derivations, or links to datasets and references.
#
# ## Exercises
# Capture practice problems, code experiments, or reflection prompts here.
